# %%
import pandas as pd
import numpy as np
import os
import fnmatch
import sys
import time
import win32com.client as win32
from datetime import datetime, timedelta
import re
import warnings

INPATH='C:\\Users\\ezbanta\\Desktop\\NDS_LTE_MINI\\'
OUTPATH='C:\\Users\\ezbanta\\Desktop\\NDS_LTE_MINI\\Output\\'
def nth_replace(string, old, new, n, option='only nth'):
    if option == 'only nth':
        left_join = old
        right_join = old
    elif option == 'all left':
        left_join = new
        right_join = old
    elif option == 'all right':
        left_join = old
        right_join = new
    else:
        print("Invalid option. Please choose from: 'only nth' (default), 'all left' or 'all right'")
        return None
    groups = string.split(old)
    nth_split = [left_join.join(groups[:n]), right_join.join(groups[n:])]
    return new.join(nth_split)

#def doProcess(INPATH,OUTPATH):
warnings.filterwarnings("ignore")
Date = time.strftime("%d%m%Y")
Time = time.strftime("%H%M%S")

for file in os.listdir(INPATH):
    if fnmatch.fnmatch(file, 'SXM EOD v4.8 Ericsson*.xlsm'):
        Filename = file
        df1 = pd.read_excel(INPATH + Filename, sheet_name="SXM EOD Drive Data", header = 1)

for file in os.listdir(INPATH):
    if fnmatch.fnmatch(file, '*NDS_LTE_MINI*.xls'):
        Filename = file
        df = pd.read_excel(INPATH + Filename, sheet_name="Power & PCI")

for file in os.listdir(INPATH):
    if fnmatch.fnmatch(file, '*NDS_LTE_MINI*.xlsx'):
        Filename = file
        df = pd.read_excel(INPATH + Filename, sheet_name="Power & PCI")

for file in os.listdir(INPATH):
    if fnmatch.fnmatch(file, '*NDS_LTE_MINI*.xls'):
        Filename = file
        df2 = pd.read_excel(INPATH + Filename, sheet_name="RET")

for file in os.listdir(INPATH):
    if fnmatch.fnmatch(file, '*NDS_LTE_MINI*.xlsx'):
        Filename = file
        df2 = pd.read_excel(INPATH + Filename, sheet_name="RET")

df2.drop(df2.tail(4).index,inplace=True)

df3=df[['ERBS','EUtranCellFDD','Configured confMaxTxPower']]
df4=df1[['Site ID','Date of Drive','Drive Pass/Fail','_3A','_3B','_3C','_3D','_3E','_3F']]
df3.rename(columns = {'EUtranCellFDD':'Cell'}, inplace = True)
df4.rename(columns = {'Site ID':'Site_ID', 'Drive Pass/Fail':'Drive_Pass_Fail'}, inplace = True)
df6=df4[df4.Drive_Pass_Fail=='Pass']

df6_1 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3A",], axis=1)
df6_2 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3B",], axis=1)
df6_3 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3C",], axis=1)
df6_4 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3D",], axis=1)
df6_5 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3E",], axis=1)
df6_6 = df6.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3F",], axis=1)

df6_1['Cell'] = df6_1['Site_ID'].str[0:8] + '_3A_1'
df6_1['end_L'] = df6_1['Site_ID'].str[8:9]
temp_x_1 = df6_1[df6_1['end_L'].str.contains("L")]
temp_x_2 = df6_1[~df6_1['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_1_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_2['Cell'] = df6_2['Site_ID'].str[0:8] + '_3B_1'
df6_2['end_L'] = df6_2['Site_ID'].str[8:9]
temp_x_1 = df6_2[df6_2['end_L'].str.contains("L")]
temp_x_2 = df6_2[~df6_2['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_2_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_3['Cell'] = df6_3['Site_ID'].str[0:8] + '_3C_1'
df6_3['end_L'] = df6_3['Site_ID'].str[8:9]
temp_x_1 = df6_3[df6_3['end_L'].str.contains("L")]
temp_x_2 = df6_3[~df6_3['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_3_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_4['Cell'] = df6_4['Site_ID'].str[0:8] + '_3D_1'
df6_4['end_L'] = df6_4['Site_ID'].str[8:9]
temp_x_1 = df6_4[df6_4['end_L'].str.contains("L")]
temp_x_2 = df6_4[~df6_4['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_4_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_5['Cell'] = df6_5['Site_ID'].str[0:8] + '_3E_1'
df6_5['end_L'] = df6_5['Site_ID'].str[8:9]
temp_x_1 = df6_5[df6_5['end_L'].str.contains("L")]
temp_x_2 = df6_5[~df6_5['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_5_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_6['Cell'] = df6_6['Site_ID'].str[0:8] + '_3F_1'
df6_6['end_L'] = df6_6['Site_ID'].str[8:9]
temp_x_1 = df6_6[df6_6['end_L'].str.contains("L")]
temp_x_2 = df6_6[~df6_6['end_L'].str.contains("L")]
temp_x_1['Cell'] = temp_x_1['Cell'] + '_L'
temp_x_1 = temp_x_1.drop(["end_L"], axis=1)
temp_x_2 = temp_x_2.drop(["end_L"], axis=1)
df6_6_final = pd.concat([temp_x_1, temp_x_2],ignore_index=True)

df6_1_final = df6_1_final.rename(columns={'_3A': 'Attenuation Val'})
df6_2_final = df6_2_final.rename(columns={'_3B': 'Attenuation Val'})
df6_3_final = df6_3_final.rename(columns={'_3C': 'Attenuation Val'})
df6_4_final = df6_4_final.rename(columns={'_3D': 'Attenuation Val'})
df6_5_final = df6_5_final.rename(columns={'_3E': 'Attenuation Val'})
df6_6_final = df6_6_final.rename(columns={'_3F': 'Attenuation Val'})

df6_con = pd.concat([df6_1_final, df6_2_final, df6_3_final, df6_4_final, df6_5_final, df6_6_final],ignore_index=True)
#df6_con = df6_con[~df6_con['Covert Power'].str.contains("NaN")]
df6_con = df6_con.astype(str).replace('\.0', '', regex=True)

dictwcs={'17':1600,'16':2000,'15':2500,'14':3200,'13':4000,'12':5000,'11':6400,'10':8000,'9':1000,'8':12800,'7':16000,'6':20000,'5':25300,'4':32000,'3':40000,'2':50400,'1':63500,'0':80000}
dictwll={'17':2000,'16':2500,'15':3200,'14':4000,'13':5000,'12':6400,'11':8000,'10':10000,'9':12500,'8':16000,'7':20000,'6':25000,'5':31600,'4':40000,'3':50000,'2':63000,'1':79500,'0':100000}


df6_merge=pd.merge(df6_con, df3, on='Cell')
df6_merge['LastDigit'] = df6_merge['Site_ID'].str[8:9]
df6_merge_1=df6_merge[(df6_merge['LastDigit'] == 'L')]
df6_merge_1['Covert Power'] = df6_merge_1["Attenuation Val"].map(dictwll)
df6_merge_2=df6_merge[(df6_merge['LastDigit'] !='L')]
df6_merge_2['Covert Power'] = df6_merge_2["Attenuation Val"].map(dictwcs)
df_sum=[df6_merge_1, df6_merge_2]
df_drop=pd.concat(df_sum)
df_tech=df_drop.dropna()
df_tech['Configured confMaxTxPower']=df_tech['Configured confMaxTxPower'].astype(int)
df_drop[['Covert Power']] = df_drop[['Covert Power']].fillna(value=0)
df_tech['Covert Power']=df_drop['Covert Power'].astype(int)
df_tech['Remarks'] = np.where(df_tech['Configured confMaxTxPower'] == df_tech['Covert Power'], True, False)

df25 = df_tech[['ERBS', 'Cell', 'Attenuation Val', 'Configured confMaxTxPower', 'Covert Power', 'Remarks']]
df25.drop(df25[df25['Remarks'] == True].index, inplace=True)
df26 = df_tech[['ERBS', 'Cell', 'Date of Drive', 'Drive_Pass_Fail', 'Attenuation Val', 'Configured confMaxTxPower', 'Covert Power', 'Remarks']]

df_sxm=df1[['Site ID','Date of Drive','Drive Pass/Fail','_3A.1','_3B.1','_3C.1','_3D.1','_3E.1','_3F.1']]

if df2.empty == False:
    df_mini=df2[['ERBS','electricalAntennaTilt','userLabel']]
    df_mini.rename(columns = {'ERBS':'Site_ID'}, inplace = True)
    df_sxm.rename(columns = {'Site ID':'Site_ID'}, inplace = True)
    df_mini['userLabel'] = df_mini['userLabel'].apply(lambda x: nth_replace(x,'-','__',3))
    df_mini['userLabel'] = df_mini['userLabel'].apply(lambda x: nth_replace(x,'__','',2))
    
    if df_mini['userLabel'].str.contains("__").any():
        df_mini[['X','Cell']]=df_mini['userLabel'].str.split("__", expand = True,n=1)
    else:
        df_mini['userLabel'] = df_mini['userLabel'].apply(lambda x: re.sub('_','__',x,1))
        df_mini[['X','Cell']] = df_mini.userLabel.str.split("__", expand = True)   
  
    df_mini["Carrier"] = df_mini["Cell"].str[8:10]
    df_mini = df_mini[df_mini['Carrier'].str.contains("_3", na=False)]
    df_mini = df_mini.drop(["X", "Carrier", "userLabel"], axis=1)
    df_sxm.rename(columns = {'Drive Pass/Fail':'Drive_Pass_Fail'}, inplace = True)
    df_x=df_sxm[df_sxm.Drive_Pass_Fail=='Pass']
    df_x = df_x.astype(str).replace('\.0', '', regex=True)
    
    df_x_1 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3A.1",], axis=1)
    df_x_2 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3B.1",], axis=1)
    df_x_3 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3C.1",], axis=1)
    df_x_4 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3D.1",], axis=1)
    df_x_5 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3E.1",], axis=1)
    df_x_6 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3F.1",], axis=1)
    
    df_x_1['Cell'] = df_x_1['Site_ID'].str[0:8] + '_3A_1'
    df_x_1['TECH'] = df_x_1['Site_ID'].str[8:9]
    temp1 = df_x_1[df_x_1['TECH'].str.contains("L")]
    temp2 = df_x_1[~df_x_1['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_1_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_2['Cell'] = df_x_2['Site_ID'].str[0:8] + '_3B_1'
    df_x_2['TECH'] = df_x_2['Site_ID'].str[8:9]
    temp1 = df_x_2[df_x_2['TECH'].str.contains("L")]
    temp2 = df_x_2[~df_x_2['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_2_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_3['Cell'] = df_x_3['Site_ID'].str[0:8] + '_3C_1'
    df_x_3['TECH'] = df_x_3['Site_ID'].str[8:9]
    temp1 = df_x_3[df_x_3['TECH'].str.contains("L")]
    temp2 = df_x_3[~df_x_3['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_3_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_4['Cell'] = df_x_4['Site_ID'].str[0:8] + '_3D_1'
    df_x_4['TECH'] = df_x_4['Site_ID'].str[8:9]
    temp1 = df_x_4[df_x_4['TECH'].str.contains("L")]
    temp2 = df_x_4[~df_x_4['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_4_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_5['Cell'] = df_x_5['Site_ID'].str[0:8] + '_3E_1'
    df_x_5['TECH'] = df_x_5['Site_ID'].str[8:9]
    temp1 = df_x_5[df_x_5['TECH'].str.contains("L")]
    temp2 = df_x_5[~df_x_5['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_5_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_6['Cell'] = df_x_6['Site_ID'].str[0:8] + '_3F_1'
    df_x_6['TECH'] = df_x_6['Site_ID'].str[8:9]
    temp1 = df_x_6[df_x_6['TECH'].str.contains("L")]
    temp2 = df_x_6[~df_x_6['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_6_final = pd.concat([temp1, temp2],ignore_index=True)
    
    
    df_x_1_final = df_x_1_final.rename(columns={'_3A.1': 'Passing electricalAntennaTilt'})
    df_x_2_final = df_x_2_final.rename(columns={'_3B.1': 'Passing electricalAntennaTilt'})
    df_x_3_final = df_x_3_final.rename(columns={'_3C.1': 'Passing electricalAntennaTilt'})
    df_x_4_final = df_x_4_final.rename(columns={'_3D.1': 'Passing electricalAntennaTilt'})
    df_x_5_final = df_x_5_final.rename(columns={'_3E.1': 'Passing electricalAntennaTilt'})
    df_x_6_final = df_x_6_final.rename(columns={'_3F.1': 'Passing electricalAntennaTilt'})
    
    df_total = pd.concat([df_x_1_final, df_x_2_final, df_x_3_final, df_x_4_final, df_x_5_final, df_x_6_final],ignore_index=True)
    df_total = df_total[~df_total['Passing electricalAntennaTilt'].str.contains("nan")]
    df_total['Passing electricalAntennaTilt']=df_total['Passing electricalAntennaTilt'].astype(float)
    df_total['Passing electricalAntennaTilt']=df_total['Passing electricalAntennaTilt'].apply(lambda x:x*10)
    
    
    #merge userlevel
    
    df_app=pd.merge(df_mini, df_total, on='Cell')
    df_app.rename(columns = {'Site_ID_x':'Site_ID'}, inplace = True)
    df_app = df_app.astype(str).replace('\.0', '', regex=True)
    
    df_app['Remarks'] = np.where(df_app['Passing electricalAntennaTilt'] == df_app['electricalAntennaTilt'], True, False)

    df_comp = df_app[['Site_ID', 'electricalAntennaTilt', 'Cell', 'Date of Drive', 'Drive_Pass_Fail', 'Passing electricalAntennaTilt', 'Remarks']]
    df_final = df_app[['Site_ID', 'electricalAntennaTilt', 'Cell', 'Passing electricalAntennaTilt', 'Remarks']]
    df_final.drop(df_final[df_final['Remarks'] == True].index, inplace=True)
else:
    df_final=pd.DataFrame(columns=['Site_ID', 'electricalAntennaTilt', 'Cell', 'Passing electricalAntennaTilt', 'Remarks'])
    df_comp = pd.DataFrame(columns=['Site_ID', 'electricalAntennaTilt', 'Cell', 'Date of Drive', 'Drive_Pass_Fail', 'Passing electricalAntennaTilt', 'Remarks'])

#Write to excel

writer = pd.ExcelWrite(OUTPATH + Time + '_SXM_EOD_TRACKER_VALIDATION_REPORT_' + Date + '.xlsx', engine='xlsxwriter')
workbook=writer.book
df25.to_excel(writer, shreet_name='Failed_Report',index=0)
df26.to_excel(writer, sheet_name='Detailed_Report',index=0)
df_final.to_excel(writer, sheet_name='Tilt_Failed_Report',index=0)
df_comp.to_excel(writer, sheet_name='Tilt_Detailed_Report',index=0)

sheet1 = writer.sheets['Failed_Report']
sheet2 = writer.sheets['Detailed_Report']
sheet3 = writer.sheets['Tilt_Failed_Report']
sheet4 = writer.sheets['Tilt_Detailed_Report']

#Formatting
cell_format = workbook.add_format()
cell_format.set_font_name('Ericsson Hilda')
cell_format.set_font_size(8)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_shrink()
cell_format.set_border(style=1)
sheet1.set_column('A:F', None, cell_format)
sheet2.set_column('A:H', None, cell_format)
sheet3.set_column('A:E', None, cell_format)
sheet4.set_column('A:G', None, cell_format)

header_format = workbook.add_format()
header_format.set_font_name('Ericsson Hilda')
header_format.set_font_size(10)
header_format.set_bold()
header_format.set_align('center')
header_format.set_align('vcenter')
header_format.set_shrink()
header_format.set_bg_color('blue')
header_format.set_font_color('white')
header_format.set_border(style=1)

for col_num, value in enumerate(df25.columns.values):
    sheet1.write(0, col_num, value, header_format)

for col_num, value in enumerate(df26.columns.values):
    sheet2.write(0, col_num, value, header_format)

for col_num, value in enumerate(df_final.columns.values):
    sheet3.write(0, col_num, value, header_format)

for col_num, value in enumerate(df_comp.columns.values):
    sheet4.write(0, col_num, value, header_format)

writer.save()

time.sleep(2)

##Email

Table = df25.to_html(index=False)
Table1 = df_final.to_html(index=False)

Table = Table.replace('<table border="1" class="dataframe">\n', '<table border="1" class="dataframe">\n  <style>\ntable, th, td {\n  border: 1px solid black;\n  border-collapse: collapse;\n  text-align: center;\n  font-family:Ericsson Hilda;\n}\n\ntable, th {\n    font-size:12px;\n    color:white;\n    background-color:blue;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n\ntable, td {\n    font-size:10px;\n    color:black;\n    background-color:white;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n</style>\n')
Table1 = Table1.replace('<table border="1" class="dataframe">\n', '<table border="1" class="dataframe">\n  <style>\ntable, th, td {\n  border: 1px solid black;\n  border-collapse: collapse;\n  text-align: center;\n  font-family:Ericsson Hilda;\n}\n\ntable, th {\n    font-size:12px;\n    color:white;\n    background-color:blue;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n\ntable, td {\n    font-size:10px;\n    color:black;\n    background-color:white;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n</style>\n') 
recipient_To='PDLSXMDTCO@pdl.internal.ericsson.com'
subject = "Power mismatch EOD with OSS"

outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.To = recipient_To
#mail.CC = recipient_cc
mail.Subject = subject


Body = """
<html>
<head></head>
<body>
<p style="color:#000000;font-size:12px;font-family:Calibri">Sir,<br><br>
We Observed the Configured Power mismatch for the below mentioned sites with EOD Sheet.<br><br>   
</p>
<br>

</font>
</body>
</html>
"""

Empty_Space = """
<html>
<head></head>
<body>
<br>
</body>
</html>
"""


mail.HTMLBody = Body + Empty_Space + Table + Empty_Space + Table1
mail.BodyFormat = 2

mail.Save()

# %%
df_mini
# Out:
# Empty DataFrame
# Columns: [Site_ID, electricalAntennaTilt, Cell]
# Index: []

# %%
if df_mini['userLabel'].str.contains("__").any():
        df_mini[['X','Cell']]=df_mini['userLabel'].str.split("__", expand = True,n=1)
# Out:
#       Site_ID  electricalAntennaTilt                      userLabel        X  \
# 0   CSL03020L                   80.0  196427A__17N                   196427A
# 1   CSL03020L                   70.0  196427A__13FCSL03020_3A_1_L__  196427A
# 2   CSL03020L                   70.0  196427A__13FCSL03020_3A_1_L__  196427A
# 3   CSL03020L                  100.0  196427B__17N                   196427B
# 4   CSL03020L                   30.0  196427B__13FCSL03020_3B_1_L__  196427B
# 5   CSL03020L                   30.0  196427B__13FCSL03020_3B_1_L__  196427B
# 6   CSL03020L                  100.0  196427C__17N                   196427C
# 7   CSL03020L                   60.0  196427C__13FCSL03020_3C_1_L__  196427C
# 8   CSL03020L                   60.0  196427C__13FCSL03020_3C_1_L__  196427C
# 9   CSL03020L                  100.0  196427E__47N                   196427E
# 10  CSL03020L                   30.0  196427E__43FCSL03020_3E_1_L__  196427E
# ...

# %%
    df_mini["Carrier"] = df_mini["Cell"].str[8:10]
    df_mini = df_mini[df_mini['Carrier'].str.contains("_3", na=False)]
    df_mini = df_mini.drop(["X", "Carrier", "userLabel"], axis=1)
    df_sxm.rename(columns = {'Drive Pass/Fail':'Drive_Pass_Fail'}, inplace = True)
    df_x=df_sxm[df_sxm.Drive_Pass_Fail=='Pass']
    df_x = df_x.astype(str).replace('\.0', '', regex=True)
    
    df_x_1 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3A.1",], axis=1)
    df_x_2 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3B.1",], axis=1)
    df_x_3 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3C.1",], axis=1)
    df_x_4 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3D.1",], axis=1)
    df_x_5 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3E.1",], axis=1)
    df_x_6 = df_x.filter(["Site_ID", "Date of Drive", "Drive_Pass_Fail", "_3F.1",], axis=1)
    
    df_x_1['Cell'] = df_x_1['Site_ID'].str[0:8] + '_3A_1'
    df_x_1['TECH'] = df_x_1['Site_ID'].str[8:9]
    temp1 = df_x_1[df_x_1['TECH'].str.contains("L")]
    temp2 = df_x_1[~df_x_1['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_1_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_2['Cell'] = df_x_2['Site_ID'].str[0:8] + '_3B_1'
    df_x_2['TECH'] = df_x_2['Site_ID'].str[8:9]
    temp1 = df_x_2[df_x_2['TECH'].str.contains("L")]
    temp2 = df_x_2[~df_x_2['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_2_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_3['Cell'] = df_x_3['Site_ID'].str[0:8] + '_3C_1'
    df_x_3['TECH'] = df_x_3['Site_ID'].str[8:9]
    temp1 = df_x_3[df_x_3['TECH'].str.contains("L")]
    temp2 = df_x_3[~df_x_3['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_3_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_4['Cell'] = df_x_4['Site_ID'].str[0:8] + '_3D_1'
    df_x_4['TECH'] = df_x_4['Site_ID'].str[8:9]
    temp1 = df_x_4[df_x_4['TECH'].str.contains("L")]
    temp2 = df_x_4[~df_x_4['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_4_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_5['Cell'] = df_x_5['Site_ID'].str[0:8] + '_3E_1'
    df_x_5['TECH'] = df_x_5['Site_ID'].str[8:9]
    temp1 = df_x_5[df_x_5['TECH'].str.contains("L")]
    temp2 = df_x_5[~df_x_5['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_5_final = pd.concat([temp1, temp2],ignore_index=True)
    
    df_x_6['Cell'] = df_x_6['Site_ID'].str[0:8] + '_3F_1'
    df_x_6['TECH'] = df_x_6['Site_ID'].str[8:9]
    temp1 = df_x_6[df_x_6['TECH'].str.contains("L")]
    temp2 = df_x_6[~df_x_6['TECH'].str.contains("L")]
    temp1['Cell'] = temp1['Cell'] + '_L'
    temp1 = temp1.drop(["TECH"], axis=1)
    temp2= temp2.drop(["TECH"], axis=1)
    df_x_6_final = pd.concat([temp1, temp2],ignore_index=True)
    
    
    df_x_1_final = df_x_1_final.rename(columns={'_3A.1': 'Passing electricalAntennaTilt'})
    df_x_2_final = df_x_2_final.rename(columns={'_3B.1': 'Passing electricalAntennaTilt'})
    df_x_3_final = df_x_3_final.rename(columns={'_3C.1': 'Passing electricalAntennaTilt'})
    df_x_4_final = df_x_4_final.rename(columns={'_3D.1': 'Passing electricalAntennaTilt'})
    df_x_5_final = df_x_5_final.rename(columns={'_3E.1': 'Passing electricalAntennaTilt'})
    df_x_6_final = df_x_6_final.rename(columns={'_3F.1': 'Passing electricalAntennaTilt'})
    
    df_total = pd.concat([df_x_1_final, df_x_2_final, df_x_3_final, df_x_4_final, df_x_5_final, df_x_6_final],ignore_index=True)
    df_total = df_total[~df_total['Passing electricalAntennaTilt'].str.contains("nan")]
    df_total['Passing electricalAntennaTilt']=df_total['Passing electricalAntennaTilt'].astype(float)
    df_total['Passing electricalAntennaTilt']=df_total['Passing electricalAntennaTilt'].apply(lambda x:x*10)
    
    
    #merge userlevel
    
    df_app=pd.merge(df_mini, df_total, on='Cell')
    df_app.rename(columns = {'Site_ID_x':'Site_ID'}, inplace = True)
    df_app = df_app.astype(str).replace('\.0', '', regex=True)
    
    df_app['Remarks'] = np.where(df_app['Passing electricalAntennaTilt'] == df_app['electricalAntennaTilt'], True, False)

    df_comp = df_app[['Site_ID', 'electricalAntennaTilt', 'Cell', 'Date of Drive', 'Drive_Pass_Fail', 'Passing electricalAntennaTilt', 'Remarks']]
    df_final = df_app[['Site_ID', 'electricalAntennaTilt', 'Cell', 'Passing electricalAntennaTilt', 'Remarks']]
    df_final.drop(df_final[df_final['Remarks'] == True].index, inplace=True)
else:
    df_final=pd.DataFrame(columns=['Site_ID', 'electricalAntennaTilt', 'Cell', 'Passing electricalAntennaTilt', 'Remarks'])
    df_comp = pd.DataFrame(columns=['Site_ID', 'electricalAntennaTilt', 'Cell', 'Date of Drive', 'Drive_Pass_Fail', 'Passing electricalAntennaTilt', 'Remarks'])

#Write to excel

writer = pd.ExcelWriter(OUTPATH + Time + '_SXM_EOD_TRACKER_VALIDATION_REPORT_' + Date + '.xlsx', engine='xlsxwriter')
workbook=writer.book
df25.to_excel(writer, sheet_name='Failed_Report',index=0)
df26.to_excel(writer, sheet_name='Detailed_Report',index=0)
df_final.to_excel(writer, sheet_name='Tilt_Failed_Report',index=0)
df_comp.to_excel(writer, sheet_name='Tilt_Detailed_Report',index=0)

sheet1 = writer.sheets['Failed_Report']
sheet2 = writer.sheets['Detailed_Report']
sheet3 = writer.sheets['Tilt_Failed_Report']
sheet4 = writer.sheets['Tilt_Detailed_Report']

#Formatting
cell_format = workbook.add_format()
cell_format.set_font_name('Ericsson Hilda')
cell_format.set_font_size(8)
cell_format.set_align('center')
cell_format.set_align('vcenter')
cell_format.set_shrink()
cell_format.set_border(style=1)
sheet1.set_column('A:F', None, cell_format)
sheet2.set_column('A:H', None, cell_format)
sheet3.set_column('A:E', None, cell_format)
sheet4.set_column('A:G', None, cell_format)

header_format = workbook.add_format()
header_format.set_font_name('Ericsson Hilda')
header_format.set_font_size(10)
header_format.set_bold()
header_format.set_align('center')
header_format.set_align('vcenter')
header_format.set_shrink()
header_format.set_bg_color('blue')
header_format.set_font_color('white')
header_format.set_border(style=1)

for col_num, value in enumerate(df25.columns.values):
    sheet1.write(0, col_num, value, header_format)

for col_num, value in enumerate(df26.columns.values):
    sheet2.write(0, col_num, value, header_format)

for col_num, value in enumerate(df_final.columns.values):
    sheet3.write(0, col_num, value, header_format)

for col_num, value in enumerate(df_comp.columns.values):
    sheet4.write(0, col_num, value, header_format)

writer.save()

time.sleep(2)

##Email

Table = df25.to_html(index=False)
Table1 = df_final.to_html(index=False)

Table = Table.replace('<table border="1" class="dataframe">\n', '<table border="1" class="dataframe">\n  <style>\ntable, th, td {\n  border: 1px solid black;\n  border-collapse: collapse;\n  text-align: center;\n  font-family:Ericsson Hilda;\n}\n\ntable, th {\n    font-size:12px;\n    color:white;\n    background-color:blue;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n\ntable, td {\n    font-size:10px;\n    color:black;\n    background-color:white;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n</style>\n')
Table1 = Table1.replace('<table border="1" class="dataframe">\n', '<table border="1" class="dataframe">\n  <style>\ntable, th, td {\n  border: 1px solid black;\n  border-collapse: collapse;\n  text-align: center;\n  font-family:Ericsson Hilda;\n}\n\ntable, th {\n    font-size:12px;\n    color:white;\n    background-color:blue;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n\ntable, td {\n    font-size:10px;\n    color:black;\n    background-color:white;\n    white-space:nowrap;\n    width:100%;\n    padding: 5px\n}\n</style>\n') 
recipient_To='PDLSXMDTCO@pdl.internal.ericsson.com'
subject = "Power mismatch EOD with OSS"

outlook = win32.Dispatch('outlook.application')
mail = outlook.CreateItem(0)
mail.To = recipient_To
#mail.CC = recipient_cc
mail.Subject = subject


Body = """
<html>
<head></head>
<body>
<p style="color:#000000;font-size:12px;font-family:Calibri">Sir,<br><br>
We Observed the Configured Power mismatch for the below mentioned sites with EOD Sheet.<br><br>   
</p>
<br>

</font>
</body>
</html>
"""

Empty_Space = """
<html>
<head></head>
<body>
<br>
</body>
</html>
"""


mail.HTMLBody = Body + Empty_Space + Table + Empty_Space + Table1
mail.BodyFormat = 2

mail.Save()
# Out:
#   File "<ipython-input-70-75425d06bb7e>", line 94
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
df25.to_excel('C:\\Users\\ezbanta\\Desktop\\NDS_LTE_MINI\\Output.xlsx')

# %%
df25[df25.select_dtypes([bool]).any(0)]

# %%
#for x in df_merge['LastDigit']:
    #if x == 'L':
        #df_merge["Covert Power"] = df_merge["Attenuation Val"].map(dict1)
    #elif x = ' ':
       # df_merge["Covert Power"] = df_merge["Attenuation Val"].map(dict2)

# %%
df24
